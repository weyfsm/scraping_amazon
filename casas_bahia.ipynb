# %%
from webdriver_manager.chrome import ChromeDriverManager
from selenium import webdriver
from selenium.webdriver.support.ui import WebDriverWait
from selenium.webdriver.common.by import By
from webdriver_manager.chrome import ChromeDriverManager
from selenium.webdriver.support import expected_conditions as EC

# %%
#from webdriver_manager.chrome import ChromeDriverManager

#driver = webdriver.Chrome(ChromeDriverManager().install())

# %%
## Prepara a página
url = 'https://www.casasbahia.com.br/geladeira/b'
driver = webdriver.Chrome(ChromeDriverManager().install())
driver.get(url)

## XPath do botão
# botao notebook, smart-tv e geladeira:
xpath = '//*[@id="__next"]/div[2]/div/div/div[5]/div[2]/div/section/div[4]/div/div/div/button'

# botao smartphone:
#xpath = '//*[@id="__next"]/div[2]/div/div/div[4]/div[2]/div/section/div[4]/div/div/div/button' 

try:
    driver.find_element_by_xpath(xpath).click()
except:
    print('Erro: Elemento não foi encontrado. Certifique-se de que o XPath está correto')

for _ in range(0,2):
        element = WebDriverWait(driver, 15).until(
                EC.presence_of_element_located((By.XPATH, xpath))
        ).click()
# Out:
# [WDM] -
#
# [WDM] - ====== WebDriver manager ======
# [WDM] - Current google-chrome version is 95.0.4638
# [WDM] - Get LATEST driver version for 95.0.4638
# [WDM] - Driver [C:\Users\weyde\.wdm\drivers\chromedriver\win32\95.0.4638.17\chromedriver.exe] found in cache

# %%
# Armazena cada item em um dict
precos = driver.find_elements_by_class_name('ProductPrice__PriceValue-sc-1tzw2we-6')
names = driver.find_elements_by_class_name('ProductCard__Title-sc-2vuvzo-0')
ratingValue = driver.find_elements_by_xpath("//meta[@itemprop='ratingValue']")
reviewCount = driver.find_elements_by_xpath("//meta[@itemprop='reviewCount']")

itens = []
for nome, n_aval, aval, preco in zip(names, reviewCount, ratingValue, precos):
    item = {'nome': nome.text,
            "num_avali": n_aval.get_attribute("content"),
            'avali': aval.get_attribute("content"),
            'preco': preco.text.split(' ')[1].replace('.','').replace(',','.'),
                    }
    itens.append(item)

# %%
import pandas as pd
data = pd.DataFrame(itens)
data
# Out:
#                                                  nome num_avali avali    preco
# 0   Refrigerador Electrolux Duplex DC35A 260L - Br...       511  4.50  1899.00
# 1   Refrigerador Consul CRM50HK Frost Free com Esp...       402   5.0  3299.00
# 2   Geladeira Consul CRD37EB Cycle Defrost com Fre...      4547   5.0  1999.00
# 3   Geladeira Consul CRM56HB Frost Free Duplex com...       803   5.0  3198.00
# 4   Geladeira Brastemp Frost Free Duplex BRM44HB c...      3741   5.0  2649.00
# ..                                                ...       ...   ...      ...
# 68  Geladeira / Refrigerador Frost Free Duplex Con...         0     0  2489.00
# 69  Refrigerador Electrolux DF44S com Prateleira R...       675   5.0  4399.00
# 70  Refrigerador Panasonic Frost Free NR-BT55PV2X ...         0     0  2459.00
# 71  Refrigerador Brastemp Frost Free Inverse 443L ...        17   5.0  4699.00
# 72  Refrigerador Consul Frost Free CRM43NK com 2 P...       885   5.0  5499.00
#
# [73 rows x 4 columns]

# %%
data.describe()
# Out:
#                                                      nome num_avali avali  \
# count                                                 263       263   263
# unique                                                250       104     5
# top     Geladeira Consul Frost Free 342 Litros Branca ...         0   5.0
# freq                                                    2        96   103
#
#           preco
# count       263
# unique      183
# top     3699.00
# freq          7

# %%
data.to_csv('geladeira_CB.csv', sep=';', encoding='utf-8', index=False)
